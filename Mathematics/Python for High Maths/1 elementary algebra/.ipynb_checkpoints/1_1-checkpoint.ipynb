# %%
a = 6
print(a)
# Out:
# 6

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
x=np.linspace(0, 10, 22)
k1=1
k2=5
plt.plot(x, np.cos(k1*x))
plt.plot(x, np.cos(k2*x))

# %%
#@title Текст заголовка по умолчанию
import torch
 
w = torch.tensor( [[1.,2.],[4.,5.]], requires_grad=True)
 
function = 10 * torch.log( ( w + 1. ) ).sum()
 
function.backward()
 
print(w-w.grad)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Temp/ipykernel_8184/145203543.py in <module>
#       1 #@title Текст заголовка по умолчанию
# ----> 2 import torch
#       3
#       4 w = torch.tensor( [[1.,2.],[4.,5.]], requires_grad=True)
#       5
#
# ModuleNotFoundError: No module named 'torch'

# %% [markdown]
# # New Section

# %%
z=input()
print(float(z)+5)
# Out:
# 5
# 10.0

# %%
print(2**8)
# Out:
# 256

# %% [markdown]
# **Текст, выделенный полужирным шрифтом**
