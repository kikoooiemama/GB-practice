# %%
  # %matplotlib inline
  import numpy as np
  import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
$\begin{matrix} a & b \\ c & d \end{matrix}$
# Out:
#   File "<ipython-input-6-1ab8687a3eca>", line 1
#     $\begin{matrix} a & b \\ c & d \end{matrix}$
#     ^
# SyntaxError: invalid syntax

# %%
# %matplotlib inline
import numpy as np
import numpy as np
import matplotlib.pyplot as plt
x=np.linspace(-2*np.pi, 3*np.pi, 201)
k=5
k1=-3
k2=0.5
a=4
a1=-3
a2=0.2
b=6
b1=-3
b2=0.4
y=k*np.cos(x-a)+b
y1=k1*np.cos(x-a1)+b1
y2=k2*np.cos(x-a2)+b2
#plt.xlable("x")
#plt.ylable("y")
plt.plot(x,y)
plt.plot(x,y1)
plt.plot(x,y2)
#plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# # Новый раздел

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,20,31)
k1=1
k2=2
k3=0.5
plt.plot(x, np.cos(k1*x))
plt.plot(x, np.cos(k2*x))
plt.plot(x, np.cos(k3*x))
